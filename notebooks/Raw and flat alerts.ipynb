# %%
from ampel.pipeline.t0.loaders.ZIAlertLoader import ZIAlertLoader

# %%
ZIAlertLoader.load_raw_dict_from_file("../alerts0/121540793515135000.avro")
# Out:
# {'alertId': 121540793515135000,
#  'candid': -121540793515135000,
#  'candidate': {'aimage': 0.6320000290870667,
#   'aimagerat': 0.2689361572265625,
#   'bimage': 0.6299999952316284,
#   'bimagerat': 0.2680850923061371,
#   'candid': -121540793515135000,
#   'chinr': 0.8240000009536743,
#   'chipsf': 1.1500054597854614,
#   'classtar': 1.0,
#   'dec': 12.7919293,
#   'decnr': 12.7916065,
#   'diffmaglim': 21.9497127532959,
#   'distnr': 2.047377586364746,
#   'elong': 1.0031746625900269,
#   'fid': 1,
#   'field': 507,
#   'fwhm': 2.3499999046325684,
#   'isdiffpos': 't',
#   'jd': 2457632.95921,
#   'jdendhist': 2457632.95921,
#   'jdstarthist': 2457632.95921,
#   'magap': 15.445599555969238,
#   'magapbig': 15.445300102233887,
#   'magdiff': 0.005900204181671143,
#   'magfromlim': 6.504112720489502,
#   'magnr': 23.06399917602539,
#   'magpsf': 15.43970012664795,
#   'mindtoedge': 94.0,
#   'nbad': 0,
#   'ncovhist': 50,
#   'ndethist': 1,
#   'nid': -122,
#   'nneg': 0,
# ...

# %%
ZIAlertLoader.get_flat_pps_list_from_file("../alerts0/121540793515135000.avro")
# Out:
# (121540793515135000,
#  [{'aimage': 0.6320000290870667,
#    'aimagerat': 0.2689361572265625,
#    'bimage': 0.6299999952316284,
#    'bimagerat': 0.2680850923061371,
#    'candid': -121540793515135000,
#    'chinr': 0.8240000009536743,
#    'chipsf': 1.1500054597854614,
#    'classtar': 1.0,
#    'dec': 12.7919293,
#    'decnr': 12.7916065,
#    'diffmaglim': 21.9497127532959,
#    'distnr': 2.047377586364746,
#    'elong': 1.0031746625900269,
#    'fid': 1,
#    'field': 507,
#    'fwhm': 2.3499999046325684,
#    'isdiffpos': 't',
#    'jd': 2457632.95921,
#    'jdendhist': 2457632.95921,
#    'jdstarthist': 2457632.95921,
#    'magap': 15.445599555969238,
#    'magapbig': 15.445300102233887,
#    'magdiff': 0.005900204181671143,
#    'magfromlim': 6.504112720489502,
#    'magnr': 23.06399917602539,
#    'magpsf': 15.43970012664795,
#    'mindtoedge': 94.0,
#    'nbad': 0,
#    'ncovhist': 50,
#    'ndethist': 1,
#    'nid': -122,
#    'nneg': 0,
# ...
